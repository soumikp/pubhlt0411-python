# %% [markdown]
# # Py Lab 3 — NumPy
# **PUBHLT 0411 · Python for Public Health Data Analysis**
#
# Name:
#
# Submit this notebook as a `.ipynb` file.
#
# ---
#
# Each exercise states the task and names the variables to create. Write your code in the empty cell below it and run the cell.
#
# Use the exact variable names given — later exercises build on them.

# %% [markdown]
# ## Before you start — the data
#
# This lab reads:
#
# - `pa_air_pollution.csv`
#
# These live in a `data/` folder next to this notebook. Run the cell below once to confirm Python can see them before you begin.

# %%
# Setup — run this cell once, before anything else.
#
# The lab's CSVs live in a `data/` folder next to this notebook. This cell
# does not download anything; it just checks Python can find them.
import os

FILES = [
    "pa_air_pollution.csv"
]

missing = [f for f in FILES if not os.path.exists(os.path.join("data", f))]

if missing:
    print("MISSING from data/:", ", ".join(missing))
    print("Working directory:", os.getcwd())
    print("Start Jupyter from the folder that holds data/, then re-run this cell.")
else:
    print("Data ready:", ", ".join(FILES))

# %% [markdown]
# ---
#
# ## Exercise 1 — Build an array
#
# These are the PM2.5 averages for six southwestern Pennsylvania counties.
# Build the array and report its length and element type.
#
# **Create:** `pm25`, `county_count`, `element_type`

# %% [markdown]
# ---
#
# ## Exercise 2 — Vectorised arithmetic
#
# Compute how far each county sits above or below the 9.0 standard. A negative
# result means the county is under it.
#
# **Create:** `pm25`, `excess`

# %% [markdown]
# ---
#
# ## Exercise 3 — Read a real file
#
# Read the county names as well, and confirm the two arrays line up.
#
# **Create:** `counties`, `pm25`, `n_counties`, `aligned`

# %% [markdown]
# ---
#
# ## Exercise 4 — Summary statistics
#
# Describe the statewide PM2.5 distribution.
#
# **Create:** `pm25`, `pm_mean`, `pm_median`, `pm_sd`

# %% [markdown]
# ---
#
# ## Exercise 5 — Boolean masking
#
# Count the counties exceeding the federal standard, and compute their share
# of the state.
#
# **Create:** `pm25`, `over_standard`, `n_over`, `share_over`

# %% [markdown]
# ---
#
# ## Exercise 6 — Apply a mask to another array
#
# Name the counties over the standard, and compare the average concentration
# above and below it.
#
# **Create:** `counties`, `pm25`, `over`, `over_names`, `mean_over`, `mean_under`

# %% [markdown]
# ---
#
# ## Exercise 7 — Combine two conditions
#
# Count the counties that exceed the standard but stay below 11.0 — over the
# limit, yet not extreme.
#
# **Create:** `pm25`, `marginal`, `n_marginal`

# %% [markdown]
# ---
#
# ## Exercise 8 — Label with `np.where()`
#
# Label all 67 counties, then confirm the labels agree with the mask count.
#
# **Create:** `pm25`, `status`, `n_labels`, `n_over_label`

# %% [markdown]
# ---
#
# ## Exercise 9 — Standardise
#
# Standardise all 67 counties and identify the outlier.
#
# **Create:** `counties`, `pm25`, `z`, `worst_position`, `worst_county`, `worst_z`

# %% [markdown]
# ---
#
# ## Exercise 10 — Two dimensions
#
# These are overdose death rates for four counties across 2019–2023. Select
# one cell, one row, and one column.
#
# **Create:** `rates`, `shape`, `philadelphia_2022`, `centre_all_years`, `all_counties_2023`

# %% [markdown]
# ---
#
# ## Exercise 11 — Collapse with `axis=`
#
# Compute the five-year average for each county, then the statewide-sample
# average for each year.
#
# **Create:** `rates`, `by_county`, `by_year`

# %% [markdown]
# ---
#
# ## Exercise 12 — Missing data
#
# Seven counties suppressed their 2023 overdose figures. Count them and
# compute the mean over the counties that reported.
#
# **Create:** `rates_2023`, `n_suppressed`, `n_reported`, `mean_reported`

# %% [markdown]
# ---
#
# ## Exercise 13 — Find the error
#
# **This code is broken.** Run it, read the error, and repair it.
#
# The objective is to count the counties that exceed the standard but stay below 11.0.
#
# **Create:** `pm25`, `marginal`, `n_marginal`
