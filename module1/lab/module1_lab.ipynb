# %% [markdown]
# # Py Lab 1 — Conditions and sequences
# **PUBHLT 0411 · Python for Public Health Data Analysis**
#
# Name:
#
# Submit this notebook as a `.ipynb` file.
#
# ---
#
# Each exercise states the task and names the variables to create. Write your code in the empty cell below it and run the cell.
#
# Use the exact variable names given — later exercises build on them.

# %% [markdown]
# ---
#
# ## Exercise 1 — Compare two rates
#
# Beaver County recorded 67 deaths in a population of 165,631. Compute its
# rate and test whether it exceeds the state rate.
#
# **Create:** `beaver_deaths`, `beaver_population`, `state_rate`, `beaver_rate`, `above_state`

# %% [markdown]
# ---
#
# ## Exercise 2 — Combine two conditions
#
# Public health planners often target **large counties with high burden**.
# Test whether Cambria County qualifies: 66 deaths, population 130,668. The thresholds are a
# population above 100,000 and a rate above the state rate.
#
# **Create:** `cambria_deaths`, `cambria_population`, `cambria_rate`, `is_priority`

# %% [markdown]
# ---
#
# ## Exercise 3 — Branch on a condition
#
# Adams County recorded 7 deaths in a population of 106,748. Report whether it
# has met the Healthy People 2030 target of 13.1 per 100,000.
#
# **Create:** `adams_deaths`, `adams_population`, `adams_rate`

# %% [markdown]
# ---
#
# ## Exercise 4 — Three-way classification
#
# Classify Lebanon County: 31 deaths, population 144,252. Use the same two
# thresholds — the state rate of 25.6 and the national target of 13.1.
#
# **Create:** `lebanon_deaths`, `lebanon_population`, `lebanon_rate`

# %% [markdown]
# ---
#
# ## Exercise 5 — Accumulate a total
#
# Total the deaths and the population across four counties, then compute the
# combined rate. Note that the combined rate is **not** the average of the four rates.
#
# **Create:** `total_deaths`, `total_population`, `combined_rate`

# %% [markdown]
# ---
#
# ## Exercise 6 — Index a string
#
# Extract the first character, the last character, and the length of
# `"Westmoreland"`.
#
# **Create:** `county`, `first_letter`, `last_letter`, `name_length`

# %% [markdown]
# ---
#
# ## Exercise 7 — Slice a string
#
# A record line begins with a four-digit year. Extract the year and the rest
# of the line separately.
#
# **Create:** `record`, `year_text`, `remainder`

# %% [markdown]
# ---
#
# ## Exercise 8 — Clean a value
#
# County Health Rankings writes `"Mc Kean"`; the Census writes `"McKean"`.
# Clean the first into the second, then confirm the two now match.
#
# **Create:** `from_rankings`, `cleaned`

# %% [markdown]
# ---
#
# ## Exercise 9 — Split a record into fields
#
# This is one line from the course data file. Extract the county name and the
# death count, converting the count to a number.
#
# **Create:** `line`, `fields`, `county`, `deaths`, `population`, `rate_per_100k`

# %% [markdown]
# ---
#
# ## Exercise 10 — Build parallel lists
#
# Build two parallel lists — `counties` and `rates` — by appending one county at
# a time: Schuylkill at 41.7, Centre at 4.4, Fayette at 62.1. Start both empty and use
# `.append()`. Then print the full list of counties, the third county with its rate, and
# whether Centre appears in the list.
#
# **Create:** `counties`, `rates`

# %% [markdown]
# ---
#
# ## Exercise 11 — Classify from a record
#
# **Putting it together.** Parse a record line, compute the rate, and classify it — the whole
# sequence in one exercise.
#
# **Create:** `line`, `fields`, `county`, `deaths`, `population`, `rate_per_100k`

# %% [markdown]
# ---
#
# ## Exercise 12 — Find the error
#
# **This code is broken.** Run it, read the error, and repair it.
#
# The objective is to report whether Lawrence County exceeds the state rate. Lawrence
# recorded 61 deaths in a population of 84,472.
#
# **Create:** `lawrence_deaths`, `lawrence_population`, `lawrence_rate`
