# %% [markdown]
# # Py Lab 2 — Collections, loops, functions, objects
# **PUBHLT 0411 · Python for Public Health Data Analysis**
#
# Name:
#
# Submit this notebook as a `.ipynb` file.
#
# ---
#
# Each exercise states the task and names the variables to create. Write your code in the empty cell below it and run the cell.
#
# Use the exact variable names given — later exercises build on them.

# %% [markdown]
# ---
#
# ## Exercise 1 — Build a dictionary
#
# These are Allegheny County's monthly COVID-19 deaths. Retrieve December's
# figure and report how many months the dictionary holds.
#
# **Create:** `allegheny`, `december_deaths`, `month_count`

# %% [markdown]
# ---
#
# ## Exercise 2 — Handle a missing key
#
# Retrieve a month that exists and one that does not, without raising.
#
# **Create:** `allegheny`, `recorded`, `absent`

# %% [markdown]
# ---
#
# ## Exercise 3 — Loop over key–value pairs
#
# Print each month alongside its death count.
#
# **Create:** `allegheny`, `months_printed`

# %% [markdown]
# ---
#
# ## Exercise 4 — Accumulate a total
#
# Total Allegheny's deaths across the six months, then compute the monthly
# average.
#
# **Create:** `allegheny`, `total_deaths`, `average`

# %% [markdown]
# ---
#
# ## Exercise 5 — Find the maximum
#
# Identify Allegheny County's deadliest month.
#
# **Create:** `allegheny`, `worst_month`, `worst_deaths`

# %% [markdown]
# ---
#
# ## Exercise 6 — Count with a condition
#
# Count the months exceeding 150 deaths, and collect their names in a list.
#
# **Create:** `allegheny`, `high_months`, `high_month_names`

# %% [markdown]
# ---
#
# ## Exercise 7 — Loop with `range()`
#
# Print each year of the pandemic period, 2020 through 2024 inclusive, and
# count them.
#
# **Create:** `years_counted`

# %% [markdown]
# ---
#
# ## Exercise 8 — Stop at the first match
#
# Identify the first month in which Allegheny exceeded 200 deaths, and stop
# searching there.
#
# **Create:** `allegheny`, `first_month`, `months_checked`

# %% [markdown]
# ---
#
# ## Exercise 9 — Write a function
#
# Write a function computing a rate per 100,000, then apply it to two counties.
#
# **Create:** `rate_per_100k`, `potter_rate`, `philadelphia_rate`

# %% [markdown]
# ---
#
# ## Exercise 10 — Return two values
#
# Return both the rate and a classification.
#
# **Create:** `summarize`, `cambria_rate`, `cambria_class`

# %% [markdown]
# ---
#
# ## Exercise 11 — Rank two ways
#
# Rank the same five counties by death count and by death rate, then compare
# the two leaders.
#
# **Create:** `counties`, `by_deaths`, `by_rate`, `top_by_deaths`, `top_by_rate`

# %% [markdown]
# ---
#
# ## Exercise 12 — Write a class
#
# Write a `County` class holding a county's `name`, `deaths` and `population`,
# with a `rate_per_100k()` method returning deaths per 100,000 residents. Build McKean County
# from it — 195 deaths, population 39,519 — and print its name and rate to one decimal place.
#
# **Create:** `mckean`

# %% [markdown]
# ---
#
# ## Exercise 13 — Find the error
#
# **This code is broken.** Run it, read the error, and repair it.
#
# The objective is to total the deaths across four months.
#
# **Create:** `allegheny`, `total_deaths`
